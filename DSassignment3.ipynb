# %%
import numpy
values1 = [10, 15, 12, 8, 14]
values2 = [18, 20, 16, 22, 25]

x1 = numpy.mean(values1)
x2 = numpy.mean(values2)

print(x1);
print(x2);
# Out:
# 11.8
# 20.2

# %%
from statistics import multimode

values = [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]

x = multimode(values)
print(x)
# Out:
# [4, 5]

# %%
import numpy 

values1 = [5000, 6000, 5500, 7000]
values2 = [4500, 5500, 5800, 6000, 5200]

x1 = numpy.median(values1)
x2 = numpy.median(values2)

print(x1)
print(x2)
# Out:
# 5750.0
# 5500.0

# %%
import numpy 

values =  [25.5, 24.8, 26.1, 25.3, 24.9]

x = numpy.ptp(values)
print(x)
# Out:
# 1.3000000000000007

# %%
import scipy.stats as stats

sample1 = [85, 90, 92, 88, 91]
sample2 = [82, 88, 90, 86, 87]

stats.ttest_ind(a=sample1,b=sample2,equal_var=True)
# Out:
# Ttest_indResult(statistic=1.4312528946642733, pvalue=0.19023970239078333)

# %%
import numpy 

values =  [160, 170, 165, 155, 175, 180, 170]

x = numpy.std(values)
print(x)
# Out:
# 7.953949089757174

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [2, 3, 5, 4, 6, 2, 4]
y = [7, 8, 6, 9, 5, 7, 6]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
from scipy import stats

x = [2, 3, 5, 4, 6, 2, 4]
y = [7, 8, 6, 9, 5, 7, 6]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

satisfaction = myfunc(5)

print(satisfaction)
# Out:
# 6.255319148936169

# %%
import numpy

values =  [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]

x = numpy.percentile(values,75)
print(x)
# Out:
# 8.75

# %%
import numpy as np
import scipy.stats as st

sample = [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]

st.t.interval(confidence=0.99,
			df=len(sample)-1,
			loc=np.mean(sample),
			scale=st.sem(sample))
# Out:
# (6.66963212044085, 9.13036787955915)

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [20, 22, 23, 19, 21]
y = [8, 7, 9, 6, 8]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
from scipy import stats

x = [2, 3, 5, 4, 6, 2, 4]
y = [7, 8, 6, 9, 5, 7, 6]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

performance = myfunc(5)

print(performance)
# Out:
# 6.255319148936169

# %%
from scipy import stats

values = [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

x = stats.iqr(values)
print(x)
# Out:
# 22.5

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [10,15,12,8,14]
y = [100,80,90,110,95]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
from scipy import stats

x = [10,15,12,8,14]
y = [100,80,90,110,95]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept
sales = myfunc(15)

print(sales)
# Out:
# 83.78048780487806

# %%
from scipy.stats import sem
 
data =  [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]

print(sem(data))
# Out:
# 0.30550504633038933
